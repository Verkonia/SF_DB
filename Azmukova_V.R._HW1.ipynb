# %% [markdown]
# # Домашняя работа №1
#
# ### 1. Структура базы данных. Нормализация
# Исходная таблица представлена в 1НФ форме.
# При помощи редактора была составлена структура базы данных
#
# Исходная база данных была нормализована, в результате чего сформировалась 5 талиц. Теперь каждая из таблиц находится в 2НФ форме, т.к. изначально таблица находилась в 1НФ форме и каждый атрибут новой таблицы теперь зависит от первичного ключа каждой таблицы.
# ![](data.JPG)

# %% [markdown]
# ### 2. Создание таблиц в DBeaver.
# При помощи программы DBeaver были созданы таблицы, указаны первичные таблицы, загружены данные в таблицы
#
# Sql-скрипт прдставлен [здесь](https://github.com/Verkonia/SF_DB/blob/master/Homework_1.sql).
#
# Скрины с загруженными данными представлены ниже.
#
# **Примечание:** для таблицы *product* , был создан суррогатный ключ *product_new_id*
#
# ![](transaction.JPG)
# ![](product.JPG)
# ![](address.JPG)
# ![](customer.JPG)
# ![](job.JPG)
